# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = fdr.DataReader('FRED:T10Y2Y', start = '2000-01-01')
df.shape
# Out:
# (6458, 1)

# %%
df.head()
# Out:
#             T10Y2Y
# DATE
# 2000-01-03    0.20
# 2000-01-04    0.19
# 2000-01-05    0.24
# 2000-01-06    0.22
# 2000-01-07    0.21

# %%
graph = df.plot()
graph.axhline(0, ls='--', color='r') # 0선
graph.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.3) # 금융위기
graph.axvspan('2020-03-01', '2020-12-30', color='gray', alpha=0.3) # 금융위기
